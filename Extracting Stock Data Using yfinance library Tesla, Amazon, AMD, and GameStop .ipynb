# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
Tesla = yf.Ticker("TSLA")
amd = yf.Ticker("AMD")
Amazon = yf.Ticker("AMZN")
GameStop = yf.Ticker("GME")

# %%
Tesla_info=Tesla.info
Tesla_info
# Out:
# {'zip': '94304',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 70757,
# ...

# %%
amd_info = amd.info
amd_info
# Out:
# {'zip': '95054',
#  'sector': 'Technology',
#  'fullTimeEmployees': 12600,
# ...

# %%
Amazon_info = Amazon.info
Amazon_info
# Out:
# {'zip': '98109-5210',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 1335000,
# ...

# %%
GameStop_info = GameStop.info
GameStop_info
# Out:
# {'zip': '76051',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 12000,
# ...

# %%
Tesla_info["country"]
# Out:
# 'United States'

# %%
amd_info['country']
# Out:
# 'United States'

# %%
Amazon_info['country']
# Out:
# 'United States'

# %%
GameStop_info['country']
# Out:
# 'United States'

# %%
Tesla_share_price_data = Tesla.history(period="max")
Tesla_share_price_data
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2010-06-29    3.800000    5.000000    3.508000    4.778000  93831500
# 2010-06-30    5.158000    6.084000    4.660000    4.766000  85935500
# 2010-07-01    5.000000    5.184000    4.054000    4.392000  41094000
# 2010-07-02    4.600000    4.620000    3.742000    3.840000  25699000
# 2010-07-06    4.000000    4.000000    3.166000    3.222000  34334500
# ...                ...         ...         ...         ...       ...
# 2021-09-17  757.150024  761.039978  750.000000  759.489990  28186100
# 2021-09-20  734.559998  742.000000  718.619995  730.169983  24757700
# 2021-09-21  734.789978  744.739990  730.440002  739.380005  16330700
# 2021-09-22  743.530029  753.669983  739.119995  751.940002  15098000
# 2021-09-23  755.000000  758.140015  747.950012  749.242493   5893064
#
#             Dividends  Stock Splits
# Date
# 2010-06-29          0           0.0
# 2010-06-30          0           0.0
# ...

# %%
amd_share_price_data = amd.history(period="max")
amd_share_price_data
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 1980-03-17    0.000000    3.302083    3.125000    3.145833    219600
# 1980-03-18    0.000000    3.125000    2.937500    3.031250    727200
# 1980-03-19    0.000000    3.083333    3.020833    3.041667    295200
# 1980-03-20    0.000000    3.062500    3.010417    3.010417    159600
# 1980-03-21    0.000000    3.020833    2.906250    2.916667    130800
# ...                ...         ...         ...         ...       ...
# 2021-09-17  105.559998  105.980003  103.709999  103.879997  44449100
# 2021-09-20  101.580002  102.510002   99.510002  101.550003  45228400
# 2021-09-21  102.150002  103.430000  101.180000  102.820000  35481500
# 2021-09-22  102.820000  104.559998  102.209999  104.379997  34067000
# 2021-09-23  104.889999  106.370003  103.889999  106.050003  17726471
#
#             Dividends  Stock Splits
# Date
# 1980-03-17          0           0.0
# 1980-03-18          0           0.0
# ...

# %%
Amazon_share_price_data = Amazon.history(period="max")
Amazon_share_price_data
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 1997-05-15     2.437500     2.500000     1.927083     1.958333  72156000
# 1997-05-16     1.968750     1.979167     1.708333     1.729167  14700000
# 1997-05-19     1.760417     1.770833     1.625000     1.708333   6106800
# 1997-05-20     1.729167     1.750000     1.635417     1.635417   5467200
# 1997-05-21     1.635417     1.645833     1.375000     1.427083  18853200
# ...                 ...          ...          ...          ...       ...
# 2021-09-17  3488.409912  3497.409912  3452.129883  3462.520020   4614100
# 2021-09-20  3396.000000  3419.000000  3305.010010  3355.729980   4669100
# 2021-09-21  3375.000000  3379.699951  3332.389893  3343.629883   2780900
# 2021-09-22  3351.000000  3389.000000  3341.050049  3380.050049   2406200
# 2021-09-23  3380.050049  3417.149902  3380.050049  3413.000000   1056231
#
#             Dividends  Stock Splits
# Date
# 1997-05-15          0           0.0
# ...

# %%
GameStop_share_price_data = GameStop.history(period="max")
GameStop_share_price_data
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2002-02-13    6.480513    6.773399    6.413183    6.766666  19054000
# 2002-02-14    6.850831    6.864296    6.682506    6.733003   2755400
# 2002-02-15    6.733001    6.749833    6.632006    6.699336   2097400
# 2002-02-19    6.665671    6.665671    6.312189    6.430017   1852600
# 2002-02-20    6.463681    6.648838    6.413183    6.648838   1723200
# ...                ...         ...         ...         ...       ...
# 2021-09-17  208.020004  212.490005  200.779999  204.970001   3945900
# 2021-09-20  200.000000  202.850006  184.550003  192.199997   3941800
# 2021-09-21  199.360001  199.360001  186.000000  189.949997   2633800
# 2021-09-22  189.639999  193.500000  186.289993  190.139999   2252600
# 2021-09-23  192.330002  195.750000  191.800095  193.040100    822157
#
#             Dividends  Stock Splits
# Date
# 2002-02-13        0.0           0.0
# 2002-02-14        0.0           0.0
# ...

# %%
Tesla_share_price_data.head()
# Out:
#              Open   High    Low  Close    Volume  Dividends  Stock Splits
# Date
# 2010-06-29  3.800  5.000  3.508  4.778  93831500          0           0.0
# 2010-06-30  5.158  6.084  4.660  4.766  85935500          0           0.0
# 2010-07-01  5.000  5.184  4.054  4.392  41094000          0           0.0
# 2010-07-02  4.600  4.620  3.742  3.840  25699000          0           0.0
# 2010-07-06  4.000  4.000  3.166  3.222  34334500          0           0.0

# %%
amd_share_price_data.head()
# Out:
#             Open      High       Low     Close  Volume  Dividends  \
# Date
# 1980-03-17   0.0  3.302083  3.125000  3.145833  219600          0
# 1980-03-18   0.0  3.125000  2.937500  3.031250  727200          0
# 1980-03-19   0.0  3.083333  3.020833  3.041667  295200          0
# 1980-03-20   0.0  3.062500  3.010417  3.010417  159600          0
# 1980-03-21   0.0  3.020833  2.906250  2.916667  130800          0
#
#             Stock Splits
# Date
# 1980-03-17           0.0
# 1980-03-18           0.0
# 1980-03-19           0.0
# 1980-03-20           0.0
# 1980-03-21           0.0

# %%
Amazon_share_price_data.head()
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 1997-05-15  2.437500  2.500000  1.927083  1.958333  72156000          0
# 1997-05-16  1.968750  1.979167  1.708333  1.729167  14700000          0
# 1997-05-19  1.760417  1.770833  1.625000  1.708333   6106800          0
# 1997-05-20  1.729167  1.750000  1.635417  1.635417   5467200          0
# 1997-05-21  1.635417  1.645833  1.375000  1.427083  18853200          0
#
#             Stock Splits
# Date
# 1997-05-15           0.0
# 1997-05-16           0.0
# 1997-05-19           0.0
# 1997-05-20           0.0
# 1997-05-21           0.0

# %%
GameStop_share_price_data.head()
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2002-02-13  6.480513  6.773399  6.413183  6.766666  19054000        0.0
# 2002-02-14  6.850831  6.864296  6.682506  6.733003   2755400        0.0
# 2002-02-15  6.733001  6.749833  6.632006  6.699336   2097400        0.0
# 2002-02-19  6.665671  6.665671  6.312189  6.430017   1852600        0.0
# 2002-02-20  6.463681  6.648838  6.413183  6.648838   1723200        0.0
#
#             Stock Splits
# Date
# 2002-02-13           0.0
# 2002-02-14           0.0
# 2002-02-15           0.0
# 2002-02-19           0.0
# 2002-02-20           0.0

# %%
Tesla_share_price_data.reset_index(inplace=True)

# %%
amd_share_price_data.reset_index(inplace=True)

# %%
Amazon_share_price_data.reset_index(inplace=True)

# %%
GameStop_share_price_data.reset_index(inplace=True)

# %%
Tesla_share_price_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
amd_share_price_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
Amazon_share_price_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
GameStop_share_price_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
Tesla_share_price_data.plot(x="Date", y="Open")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
amd_share_price_data.plot(x="Date", y="Open")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Amazon_share_price_data.plot(x="Date", y="Open")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
GameStop_share_price_data.plot(x="Date", y="Open")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Tesla.dividends
# Out:
# Series([], Name: Dividends, dtype: int64)

# %%
amd.dividends
# Out:
# Series([], Name: Dividends, dtype: int64)

# %%
Amazon.dividends
# Out:
# Series([], Name: Dividends, dtype: int64)

# %%
GameStop.dividends
# Out:
# Date
# 2012-02-16    0.150
# 2012-05-24    0.150
# 2012-08-24    0.250
# 2012-11-26    0.250
# 2013-03-01    0.275
# 2013-05-31    0.275
# 2013-08-29    0.275
# 2013-12-02    0.275
# 2014-03-13    0.330
# 2014-06-02    0.330
# 2014-08-29    0.330
# 2014-11-21    0.330
# 2015-03-13    0.360
# 2015-06-08    0.360
# 2015-09-04    0.360
# 2015-12-01    0.360
# 2016-03-04    0.370
# 2016-06-06    0.370
# 2016-09-07    0.370
# 2016-11-29    0.370
# 2017-03-10    0.380
# 2017-06-05    0.380
# 2017-09-07    0.380
# 2017-11-30    0.380
# 2018-03-02    0.380
# 2018-06-11    0.380
# 2018-09-17    0.380
# 2018-12-10    0.380
# 2019-03-14    0.380
# Name: Dividends, dtype: float64

# %%
Tesla.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
amd.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Amazon.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
GameStop.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
amd_info['sector']

# %%
amd_share_price_data.iloc[0][6]

# %%
amd_share_price_data["Volume"][0]
